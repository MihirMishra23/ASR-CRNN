# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa, librosa.display
import numpy as np
from scipy.io.wavfile import write
import os
from pathlib import Path
import pandas as pd
from IPython.display import Audio

# %%
x, sr = librosa.load("train/audio/bed/3ff840aa_nohash_0.wav")
plt.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)
plt.title("Audio File Graph of Spoken Word \"Bed\" Before Processing")
plt.ylabel("Amplitude")
Audio(data=x, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
x, sr = librosa.load("train/audio/bed/3ff840aa_nohash_0.wav")
mfcc = librosa.feature.mfcc(x, sr=sr)
plt.figure(figsize=(14, 5))
librosa.display.specshow(mfcc, x_axis='time')
plt.title("Mel Frequency Cepstrum Coefficients Graph of a Spoken \"Bed\"")
plt.ylabel("Coefficient")
# Out:
# /var/folders/dn/zvn6jgsj7c5bbww7rzdblz1w0000gn/T/ipykernel_88390/1715011940.py:2: FutureWarning: Pass y=[ 2.4363866e-04  4.0708316e-04  4.2764453e-04 ... -1.4976150e-04
#  -1.3689922e-04 -6.0305436e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mfcc = librosa.feature.mfcc(x, sr=sr)
# Text(0, 0.5, 'Coefficient')
